# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import librosa

directory1 = '/content/drive/My Drive/clips/burping'
for filename in os.listdir(directory1):
  if filename.endswith(".wav") :
    
   fname = directory1 + '/' + filename
   string = '.wav'
   newfname = filename[:-(len(string))]
   print(fname)
   y, sr = librosa.load(fname,sr=8000) 
   y_shifted = librosa.effects.pitch_shift(y, sr, n_steps=3,bins_per_octave=24) 
   librosa.output.write_wav('/content/drive/My Drive/clips/burping/pitch_shift/%s0.wav' % newfname, y_shifted, 8000,norm=False)

directory2 = '/content/drive/My Drive/clips/belly_pain'
for filename in os.listdir(directory2):
  if filename.endswith(".wav") :
    
   fname = directory2 + '/' + filename
   string = '.wav'
   newfname = filename[:-(len(string))]
   print(fname)
   y, sr = librosa.load(fname,sr=8000) 
   y_shifted = librosa.effects.pitch_shift(y, sr, n_steps=3,bins_per_octave=24) 
   librosa.output.write_wav('/content/drive/My Drive/clips/belly_pain/pitch_shift/%s0.wav' % newfname, y_shifted, 8000,norm=False) 

directory3 = '/content/drive/My Drive/clips/discomfort'
for filename in os.listdir(directory3):
  if filename.endswith(".wav") :
    
   fname = directory3 + '/' + filename
   string = '.wav'
   newfname = filename[:-(len(string))]
   print(fname)
   y, sr = librosa.load(fname,sr=8000) 
   y_shifted = librosa.effects.pitch_shift(y, sr, n_steps=3,bins_per_octave=24) 
   librosa.output.write_wav('/content/drive/My Drive/clips/discomfort/pitch_shift/%s0.wav' % newfname, y_shifted, 8000,norm=False)     

directory4 = '/content/drive/My Drive/clips/tired'
for filename in os.listdir(directory4):
  if filename.endswith(".wav") :
    
   fname = directory4 + '/' + filename
   string = '.wav'
   newfname = filename[:-(len(string))]
   print(fname)
   y, sr = librosa.load(fname,sr=8000) 
   y_shifted = librosa.effects.pitch_shift(y, sr, n_steps=3,bins_per_octave=24) 
   librosa.output.write_wav('/content/drive/My Drive/clips/tired/pitch_shift/%s0.wav' % newfname, y_shifted, 8000,norm=False)
# Out:
# /content/drive/My Drive/clips/burping/7A864194-4B6B-4850-ABBF-0C2A8170107B-1436846915-1.1-f-26-bu.wav
# /content/drive/My Drive/clips/burping/5afc6a14-a9d8-45f8-b31d-c79dd87cc8c6-1430757039803-1.7-m-48-bu.wav
# /content/drive/My Drive/clips/burping/7E4B9C14-F955-4BED-9B03-7F3096A6CBFF-1430232208-1.0-f-26-bu.wav
# /content/drive/My Drive/clips/burping/7E4B9C14-F955-4BED-9B03-7F3096A6CBFF-1430540826-1.0-f-26-bu.wav
# /content/drive/My Drive/clips/burping/79FF400A-97E2-4701-987D-C7C850D5523C-1430089648-1.0-f-48-bu.wav
# /content/drive/My Drive/clips/burping/af30880e-5f98-4dc0-b37a-be6b21fa0ba3-1431240072536-1.7-m-26-bu.wav
# /content/drive/My Drive/clips/burping/F24DE44B-762C-4149-AC92-96A5E57ED118-1430816949-1.0-m-04-bu.wav
# /content/drive/My Drive/clips/burping/AEA8AE04-D00E-48A7-8A0B-6D87E2175121-1430563241-1.0-f-72-bu.wav
# /content/drive/My Drive/clips/belly_pain/549a46d8-9c84-430e-ade8-97eae2bef787-1430130772174-1.7-m-48-bp.wav
# ...
